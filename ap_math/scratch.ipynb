# %%
from matplotlib import pyplot as plt
import result_processor

# %%
_, data = result_processor.get_values()
bests = [6,33,80,153,262,419,599,828,1138,1421,1878,2282,2817,3347,4002,4875,5642,6323,7228,8422,9760,10890,12187,13140,14752]
ns = [2, 6, 11, 18, 27, 38, 50, 65, 81, 98, 118, 139, 162, 187, 214, 242, 273, 305, 338, 374, 411, 450, 491, 534, 578]
n_squareds = [n*n for n in ns]
i = range(len(ns))

# %%
plt.plot(ns, data)
plt.plot(ns, bests)

# %%
plt.plot(i, data)
plt.plot(i, bests)

# %%
plt.plot(ns[:10], data[:10])
plt.plot(ns[:10], bests[:10])
